# %% [markdown]
# # Car Racing DQN agent
# Training a DQN agent for the OpenAI gym Car-Racing-v0 environment.
#
#
# ### Notes
# - The first 50 frames afer resetting the environment are of the camera zooming into the track, and look very different from "normal" gameplay.
#     - I exclude these frames from the training of each episode.
# - Preprocessing
#     - I have applied similar preprocessing steps as used in the DeepMind paper.
#     - Images are converted to grayscale and cropped to $56 x 56$ to reduce dimensionality and speed up training.
#     - Consecutive frames are then stacked to form a $56 x 56 x 3$ image, where the channels represent the game screen at different points in time instead of RGB channels.
# - How often the target network weights are updated seems to make a BIG difference on training performance. Less seems to be more.
#
# ### To do
# - Research literature.
# - Increase replay buffer size.
# - Trial simplified CNN architectures.
# - Add more frames to the frame stack.
# - Adjust max consecutive negative rewards threholds.
# - Trial different epsilon decay schedules.
#
# ### Environment setup
#
#         conda create -c conda-forge -n gymenv swig pip
#         conda activate gymenv
#         pip install gym==0.19.0
#         pip install Box2D gym
#         pip install gym[all]
#
#         pip install tensorflow
#         pip install matplotlib
#
#         pip install gym pyvirtualdisplay
#         sudo apt-get install -y xvfb python-opengl ffmpeg
#
#         # The following steps are so that I can access the new env in Azure ML notebooks
#         conda install ipykernel
#         python -m ipykernel install --user --name gymenv --display-name "Python (gymenv)"
#
#
#
#
# ### Useful links
#
# #### Papers
# https://arxiv.org/pdf/1312.5602.pdf
#
# #### Environment setup
# https://stackoverflow.com/questions/60268769/gyms-box-2d-openai-doesnt-install-successfully-pip-error
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-access-terminal#add-new-kernels
#
# #### Code adapted from:
# https://keras.io/examples/rl/deep_q_network_breakout/
# https://towardsdatascience.com/reinforcement-learning-w-keras-openai-dqns-1eed3a5338c
# https://pythonprogramming.net/training-deep-q-learning-dqn-reinforcement-learning-python-tutorial/?completed=/deep-q-learning-dqn-reinforcement-learning-python-tutorial/
# https://github.com/andywu0913/OpenAI-GYM-CarRacing-DQN
# https://github.com/pekaalto/DQN

# %% [markdown]
# #### Import libraries

# %%
import gym
import numpy as np
from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from collections import deque
from itertools import permutations
import random
import matplotlib.pyplot as plt
from keras.models import Sequential, load_model, Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Input, \
                        GlobalMaxPool2D, BatchNormalization, Dropout, Activation
from keras.backend import clear_session

display = Display(visible=0, size=(1400, 900))
display.start()

# %% [markdown]
# ## Train the DQN agent

# %%
def create_q_model():
    """Returns a CNN model - same architecture as in the DeepMind paper."""

    model = Sequential()
    model.add(Conv2D(32, 8, activation='relu', strides=4,
            input_shape=(56, 56, 3,)))
    model.add(Conv2D(64, 4, activation='relu', strides=2))
    model.add(Conv2D(64, 3, activation='relu', strides=1))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dense(num_actions, activation="linear"))

    return model


def image_processing(s):
    """Crop image, convert to grayscale and reshape."""

    s = s[20:76, 20:76, :]
    s = np.dot(s[...,:3], [0.2989, 0.5870, 0.1140]).astype(np.int16)
    s = np.reshape(s, (1, 56, 56))

    return s


def experience_replay(d, model, target_model, verbose=False):
    """Experience replay step."""

    # Create random batch from replay buffer
    batch = random.sample(d, BATCH_SIZE)

    # Get states
    s_0 = np.array([np.reshape(x[0], (56, 56, 3)) for x in batch])
    s_1 = np.array([np.reshape(x[3], (56, 56, 3)) for x in batch])

    # Get q values from models
    q_0 = model.predict(s_0)
    q_1 = target_model.predict(s_1)

    # Create empty lists for training
    s = []
    y = []

    # Loop through batch and update q-values
    for i, (_, a, r, _, done) in enumerate(batch):
        if done:
            q_new = r
        else: 
            q_new = r + GAMMA * max(q_1[i])

        # Update the q-value
        q_0[i][a] = q_new 

    # Fit model
    model.fit(s_0, q_0, epochs=1, batch_size=BATCH_SIZE, verbose=verbose)


def get_stacked_state(gs_buffer):
    """Returns a stacked image from the grayscale buffer."""

    # Create image from grayscale buffer
    img = np.zeros((56, 56, 3))
    img[:, :, 0] = gs_buffer[0]
    img[:, :, 1] = gs_buffer[1]
    img[:, :, 2] = gs_buffer[2]
    img = np.reshape(img, (1, 56, 56, 3))

    # Remove first image from buffer
    gs_buffer.popleft()
    return img


def generate_episode(s_0, env, d, actions, epsilon, frame_count):
    """Generate an episode of learning."""
    
    episode_reward = 0
    episode_frame_count = 0
    consecutive_negative_rewards = 0

    # Get stacked state representation
    s_0 = image_processing(s_0)
    grayscale_state_buffer = deque([s_0]*3)
    s_0_stacked = get_stacked_state(grayscale_state_buffer)

    while True:

        # Increment counters
        episode_frame_count += 1
        frame_count += 1

        # Select action
        if frame_count < RANDOM_ACTION_FRAMES or np.random.rand() < epsilon:
            a_0 = np.random.choice(np.arange(num_actions), p=PROBS)
            #a_0 = random.choice(np.arange(num_actions))
        else:
            a_0 = np.argmax(model.predict(s_0_stacked))

        # Action reward aggregates rewards over the skip frame loop
        action_reward = 0
        for _ in range(SKIP_FRAMES):
            # Take action and reshape new state
            s_1, reward, done, _ = env.step(actions[a_0])
            s_1 = image_processing(s_1)
            
            action_reward += reward
            episode_reward += reward
            if done:
                break

        # Increment consecutive negative reward counter
        if action_reward < 0:
            consecutive_negative_rewards += 1 
        else: 
            consecutive_negative_rewards = 0

        # Append latest state and get new stacked representation
        grayscale_state_buffer.append(s_1)
        s_1_stacked = get_stacked_state(grayscale_state_buffer)

        # Append (s, a, r, s') to d
        d.append((s_0_stacked, a_0, action_reward, s_1_stacked, done))

        # Start experience replay
        if len(d) >= MIN_REPLAY_MEMORY_SIZE:
            verbose = True if frame_count % VERBOSE_N == 0 else False
            experience_replay(d, model, target_model, verbose)

        # Drop a random experience if the length of d exceeeds MAX_REPLAY_MEMORY_SIZE
        if len(d) > MAX_REPLAY_MEMORY_SIZE:
            #d.pop(random.randrange(len(d)))
            d.popleft()

        # Set target weights to model weights
        if frame_count % UPDATE_TARGET_MODEL_FRAMES == 0:
            target_model.set_weights(model.get_weights())

        # Save model
        if frame_count % SAVE_TRAINING_FREQUENCY == 0 and SAVE_MODELS is True:
            model.save(f'./saved_models/dqn_trial_{frame_count}.h5')

        # End the episode if following conditions are met
        if done or (episode_frame_count > MAX_FRAMES_PER_EPISODE) or (consecutive_negative_rewards > MAX_CONSECUTIVE_NEGATIVE_REWARDS):
            print(f"Ending episode: done {done}, consecutive negative rewards {consecutive_negative_rewards}")
            print(f"Total frames in episode: {episode_frame_count}")
            break

        # Current state ← new state
        s_0_stacked = s_1_stacked.copy()

    print(f'Replay buffer size: {len(d)}')
    return d, episode_reward, epsilon, frame_count


def dqn_agent(s, actions, model):
    """Returns the best action as learnt by the DQN agent."""
    s = np.reshape(s, (1, 96, 96, 3))
    action_index = np.argmax(model.predict(s))
    return actions[action_index]

# %%
# Discretize actions
actions = np.array([[0.0, 1.0, 0.0],  # Full throttle
                    [1.0, 1.0, 0.0],
                    [-1.0, 1.0, 0.0],
                    [-1.0, 0.8, 0.0],  # Full left, half throttle
                    [1.0, 0.8, 0.0],   # Full right, half throttle
                    [-1.0, 0.0, 0.2], # Full left, quarter brake
                    [1.0, 0.0, 0.2],  # Full right, quarter brake
                    [0.0, 0.0, 0.2],  # Quarter brake
                    [0.0, 0.0, 0.0]]   # No action
                   )

num_actions = actions.shape[0]

# When selecting random actions, put more weight on actions that move forward.
# This seem to speed up training considerably.
PROBS = [0.3, 0.15, 0.15] + [(1 - 0.6)/6.0] * 6
sum(PROBS)
# Out:
# 0.9999999999999999

# %%
# Init constants
NUMBER_OF_EPISODES = 400
GAMMA = 0.95
EPSILON_MIN = 0.1
EPSILON_DECAY = 0.999
EPSILON_STEP_EPISODES = 200.0
EPSILON_STEP = (1.0 - EPSILON_MIN)/EPSILON_STEP_EPISODES
MAX_REPLAY_MEMORY_SIZE = 50000
MIN_REPLAY_MEMORY_SIZE = 1000
RANDOM_ACTION_FRAMES = 2000
MAX_CONSECUTIVE_NEGATIVE_REWARDS = 50
BATCH_SIZE = 32
UPDATE_TARGET_MODEL_FRAMES = 2000
MAX_FRAMES_PER_EPISODE = 10000
SKIP_FRAMES = 4
SAVE_TRAINING_FREQUENCY = 5000
SAVE_MODELS = False
VERBOSE_N = 50

# Create models
clear_session()
target_model = create_q_model()
model = create_q_model()
loss_function = keras.losses.Huber()
opt = Adam(learning_rate=0.00025, epsilon=1e-7, clipnorm=1.0)
model.compile(loss=loss_function, optimizer=opt, metrics=['mean_squared_error'])
target_model.compile(loss=loss_function, optimizer=opt, metrics=['mean_squared_error'])

# Init variables
epsilon = 1.0
d = deque()
episode_rewards =[]
average_rewards = []
frame_count = 0
env = gym.make("CarRacing-v0")

# Train the agent!
for i in range(NUMBER_OF_EPISODES):
    print(f'Episode: {i}')
    # Reset the environment
    _ = env.reset()

    # First 50 frames are zooming into track so ignore for training!
    for _ in range(50):
        s_0, _, _, _ = env.step([0.0, 1.0, 0.0])

    # Generate episode
    d, episode_reward, epsilon, frame_count = generate_episode(s_0, env, d, actions, epsilon, frame_count)
    episode_rewards.append(episode_reward)

    print(f'Total frame count: {frame_count}')
    print(f'Epsilon: {epsilon}')
    print(f'Total reward for episode: {episode_reward}')
    print(f'Running average rewards: {np.mean(episode_rewards)} \n')

    # Start decaying epsilon when policy is used to select actions
    if frame_count > RANDOM_ACTION_FRAMES and frame_count > MIN_REPLAY_MEMORY_SIZE:
        epsilon =  max(EPSILON_MIN, epsilon - EPSILON_STEP)

env.close()
# Out:
# Episode: 0
# Track generation: 1215..1522 -> 307-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 56
# Total frame count: 56
# Epsilon: 1.0
# Total reward for episode: -6.060130718954561
# Running average rewards: -6.060130718954561
#
# Episode: 1
# Track generation: 1122..1406 -> 284-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 111
# Total frame count: 111
# Epsilon: 1.0
# Total reward for episode: -7.8657243816257605
# Running average rewards: -6.962927550290161
#
# Episode: 2
# Track generation: 1048..1316 -> 268-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1152..1444 -> 292-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 167
# Total frame count: 167
# Epsilon: 1.0
# Total reward for episode: -1.781443298969382
# Running average rewards: -5.235766133183234
#
# Episode: 3
# Track generation: 1143..1433 -> 290-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 223
# Total frame count: 223
# Epsilon: 1.0
# Total reward for episode: -5.098961937716577
# Running average rewards: -5.20156508431657
#
# Episode: 4
# Track generation: 1172..1469 -> 297-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 280
# Total frame count: 280
# Epsilon: 1.0
# Total reward for episode: 0.8486486486483251
# Running average rewards: -3.991522337723591
#
# Episode: 5
# Track generation: 1176..1481 -> 305-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 71
# Replay buffer size: 351
# Total frame count: 351
# Epsilon: 1.0
# Total reward for episode: 37.389473684211566
# Running average rewards: 2.905310332598935
#
# Episode: 6
# Track generation: 1063..1333 -> 270-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 406
# Total frame count: 406
# Epsilon: 1.0
# Total reward for episode: -7.130111524163883
# Running average rewards: 1.4716786387756753
#
# Episode: 7
# Track generation: 1144..1435 -> 291-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 462
# Total frame count: 462
# Epsilon: 1.0
# Total reward for episode: -5.158620689655486
# Running average rewards: 0.6428912227217798
#
# Episode: 8
# Track generation: 1124..1409 -> 285-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 517
# Total frame count: 517
# Epsilon: 1.0
# Total reward for episode: -7.915492957746782
# Running average rewards: -0.3080403528858382
#
# Episode: 9
# Track generation: 1033..1295 -> 262-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 572
# Total frame count: 572
# Epsilon: 1.0
# Total reward for episode: -6.67432950191602
# Running average rewards: -0.9446692677888564
#
# Episode: 10
# Track generation: 1148..1439 -> 291-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 628
# Total frame count: 628
# Epsilon: 1.0
# Total reward for episode: -5.158620689655486
# Running average rewards: -1.3277557606858226
#
# Episode: 11
# Track generation: 1064..1338 -> 274-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 70
# Replay buffer size: 698
# Total frame count: 698
# Epsilon: 1.0
# Total reward for episode: 41.59706959707096
# Running average rewards: 2.249313019127243
#
# Episode: 12
# Track generation: 1068..1346 -> 278-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 86
# Replay buffer size: 784
# Total frame count: 784
# Epsilon: 1.0
# Total reward for episode: 12.531407942237799
# Running average rewards: 3.0402433978280547
#
# Episode: 13
# Track generation: 1209..1515 -> 306-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 840
# Total frame count: 840
# Epsilon: 1.0
# Total reward for episode: -6.006557377049489
# Running average rewards: 2.3940433424796588
#
# Episode: 14
# Track generation: 1105..1386 -> 281-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 896
# Total frame count: 896
# Epsilon: 1.0
# Total reward for episode: -4.542857142857464
# Running average rewards: 1.9315833101238506
#
# Episode: 15
# Track generation: 1208..1514 -> 306-tiles track
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 953
# Total frame count: 953
# Epsilon: 1.0
# Total reward for episode: -3.127868852459329
# Running average rewards: 1.6153675499624025
#
# Episode: 16
# Track generation: 1151..1443 -> 292-tiles track
# 1/1 [==============================] - 1s 571ms/step - loss: 3.2207 - mean_squared_error: 173.9561
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 1009
# Total frame count: 1009
# Epsilon: 1.0
# Total reward for episode: -1.781443298969382
# Running average rewards: 1.4155551470840622
#
# Episode: 17
# Track generation: 1169..1466 -> 297-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0840 - mean_squared_error: 0.2545
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 1065
# Total frame count: 1065
# Epsilon: 1.0
# Total reward for episode: -5.508108108108427
# Running average rewards: 1.0309071884622574
#
# Episode: 18
# Track generation: 1087..1365 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1260..1579 -> 319-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1332 - mean_squared_error: 0.5373
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 1121
# Total frame count: 1121
# Epsilon: 1.0
# Total reward for episode: -6.676729559748736
# Running average rewards: 0.6252420964511524
#
# Episode: 19
# Track generation: 1227..1538 -> 311-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1134 - mean_squared_error: 0.5647
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 1176
# Total frame count: 1176
# Epsilon: 1.0
# Total reward for episode: -9.096774193548677
# Running average rewards: 0.13914128195116088
#
# Episode: 20
# Track generation: 1124..1415 -> 291-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1287 - mean_squared_error: 0.3943
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 1231
# Total frame count: 1231
# Epsilon: 1.0
# Total reward for episode: -8.206896551724448
# Running average rewards: -0.258289091081011
#
# Episode: 21
# Track generation: 1246..1562 -> 316-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1143 - mean_squared_error: 0.3481
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 1287
# Total frame count: 1287
# Epsilon: 1.0
# Total reward for episode: -3.35238095238126
# Running average rewards: -0.3989296302310223
#
# Episode: 22
# Track generation: 1072..1344 -> 272-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2297 - mean_squared_error: 0.8706
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 1344
# Total frame count: 1344
# Epsilon: 1.0
# Total reward for episode: -4.3498154981553085
# Running average rewards: -0.570707276662513
#
# Episode: 23
# Track generation: 1138..1426 -> 288-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0588 - mean_squared_error: 0.1495
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0938 - mean_squared_error: 0.3480
# Ending episode: done False, negative rewards 51
# Total frames in episode: 58
# Replay buffer size: 1402
# Total frame count: 1402
# Epsilon: 1.0
# Total reward for episode: 4.674564459929968
# Running average rewards: -0.3521542876378261
#
# Episode: 24
# Track generation: 1371..1718 -> 347-tiles track
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1498 - mean_squared_error: 0.4980
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 1458
# Total frame count: 1458
# Epsilon: 1.0
# Total reward for episode: -5.058959537572571
# Running average rewards: -0.5404264976352159
#
# Episode: 25
# Track generation: 1000..1262 -> 262-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1698 - mean_squared_error: 0.5738
# Ending episode: done False, negative rewards 51
# Total frames in episode: 58
# Replay buffer size: 1516
# Total frame count: 1516
# Epsilon: 1.0
# Total reward for episode: 3.6199233716471824
# Running average rewards: -0.3804130411243544
#
# Episode: 26
# Track generation: 1144..1434 -> 290-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1375 - mean_squared_error: 0.4526
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 1571
# Total frame count: 1571
# Epsilon: 1.0
# Total reward for episode: -8.15916955017332
# Running average rewards: -0.668515134052094
#
# Episode: 27
# Track generation: 1104..1389 -> 285-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1981 - mean_squared_error: 0.7275
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0723 - mean_squared_error: 0.1831
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1181 - mean_squared_error: 0.3910
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1915 - mean_squared_error: 0.7298
# Ending episode: done False, negative rewards 51
# Total frames in episode: 186
# Replay buffer size: 1757
# Total frame count: 1757
# Epsilon: 1.0
# Total reward for episode: 41.7971830985931
# Running average rewards: 0.8481169456852344
#
# Episode: 28
# Track generation: 1127..1413 -> 286-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1654 - mean_squared_error: 0.5687
# Ending episode: done False, negative rewards 51
# Total frames in episode: 61
# Replay buffer size: 1818
# Total frame count: 1818
# Epsilon: 1.0
# Total reward for episode: 17.705263157894464
# Running average rewards: 1.4293978495545183
#
# Episode: 29
# Track generation: 1270..1592 -> 322-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1362 - mean_squared_error: 0.3988
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 1874
# Total frame count: 1874
# Epsilon: 1.0
# Total reward for episode: -6.823676012461377
# Running average rewards: 1.1542953874873219
#
# Episode: 30
# Track generation: 1198..1510 -> 312-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1797 - mean_squared_error: 0.6454
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 1931
# Total frame count: 1931
# Epsilon: 1.0
# Total reward for episode: -3.5073954983925972
# Running average rewards: 1.0039182621363567
#
# Episode: 31
# Track generation: 1077..1349 -> 272-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1210 - mean_squared_error: 0.4285
# Ending episode: done False, negative rewards 51
# Total frames in episode: 65
# Replay buffer size: 1996
# Total frame count: 1996
# Epsilon: 1.0
# Total reward for episode: 18.2804428044279
# Running average rewards: 1.5438096540829673
#
# Episode: 32
# Track generation: 1017..1278 -> 261-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1083..1358 -> 275-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1323 - mean_squared_error: 0.4175
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2099 - mean_squared_error: 0.7958
# Ending episode: done False, negative rewards 51
# Total frames in episode: 92
# Replay buffer size: 2088
# Total frame count: 2088
# Epsilon: 1.0
# Total reward for episode: 32.543065693432105
# Running average rewards: 2.483181049214759
#
# Episode: 33
# Track generation: 1075..1348 -> 273-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1036 - mean_squared_error: 0.2842
# Ending episode: done False, negative rewards 51
# Total frames in episode: 58
# Replay buffer size: 2146
# Total frame count: 2146
# Epsilon: 0.9955
# Total reward for episode: -1.141176470588551
# Running average rewards: 2.376582298632309
#
# Episode: 34
# Track generation: 1006..1267 -> 261-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1935 - mean_squared_error: 0.6356
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1024 - mean_squared_error: 0.3597
# Ending episode: done False, negative rewards 51
# Total frames in episode: 73
# Replay buffer size: 2219
# Total frame count: 2219
# Epsilon: 0.9910000000000001
# Total reward for episode: 16.95384615384598
# Running average rewards: 2.793075551638414
#
# Episode: 35
# Track generation: 1083..1358 -> 275-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2596 - mean_squared_error: 1.0796
# Ending episode: done False, negative rewards 51
# Total frames in episode: 58
# Replay buffer size: 2277
# Total frame count: 2277
# Epsilon: 0.9865000000000002
# Total reward for episode: 5.997080291970462
# Running average rewards: 2.882075683314304
#
# Episode: 36
# Track generation: 1161..1455 -> 294-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0561 - mean_squared_error: 0.1403
# Ending episode: done False, negative rewards 51
# Total frames in episode: 68
# Replay buffer size: 2345
# Total frame count: 2345
# Epsilon: 0.9820000000000002
# Total reward for episode: 20.581569965870152
# Running average rewards: 3.3604403936536515
#
# Episode: 37
# Track generation: 1083..1358 -> 275-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1418 - mean_squared_error: 0.4157
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0439 - mean_squared_error: 0.1088
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 2402
# Total frame count: 2402
# Epsilon: 0.9775000000000003
# Total reward for episode: 2.747445255474119
# Running average rewards: 3.344308942648927
#
# Episode: 38
# Track generation: 1203..1508 -> 305-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1089 - mean_squared_error: 0.5254
# Ending episode: done False, negative rewards 51
# Total frames in episode: 59
# Replay buffer size: 2461
# Total frame count: 2461
# Epsilon: 0.9730000000000003
# Total reward for episode: 9.294736842104939
# Running average rewards: 3.496884016993953
#
# Episode: 39
# Track generation: 1267..1588 -> 321-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0580 - mean_squared_error: 0.1485
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 2517
# Total frame count: 2517
# Epsilon: 0.9685000000000004
# Total reward for episode: -6.775000000000318
# Running average rewards: 3.2400869165690964
#
# Episode: 40
# Track generation: 1159..1453 -> 294-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0704 - mean_squared_error: 0.1735
# Ending episode: done False, negative rewards 51
# Total frames in episode: 58
# Replay buffer size: 2575
# Total frame count: 2575
# Epsilon: 0.9640000000000004
# Total reward for episode: 0.6907849829348365
# Running average rewards: 3.1779088206267976
#
# Episode: 41
# Track generation: 1191..1493 -> 302-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0335 - mean_squared_error: 0.0724
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 2631
# Total frame count: 2631
# Epsilon: 0.9595000000000005
# Total reward for episode: -2.466445182724577
# Running average rewards: 3.043519439594622
#
# Episode: 42
# Track generation: 1260..1578 -> 318-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0119 - mean_squared_error: 0.0264
# Ending episode: done False, negative rewards 51
# Total frames in episode: 67
# Replay buffer size: 2698
# Total frame count: 2698
# Epsilon: 0.9550000000000005
# Total reward for episode: 11.054889589905002
# Running average rewards: 3.2298303733227702
#
# Episode: 43
# Track generation: 1053..1326 -> 273-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0816 - mean_squared_error: 0.3495
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0549 - mean_squared_error: 0.1217
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0825 - mean_squared_error: 0.2393
# Ending episode: done False, negative rewards 51
# Total frames in episode: 107
# Replay buffer size: 2805
# Total frame count: 2805
# Epsilon: 0.9505000000000006
# Total reward for episode: 1.3176470588229492
# Running average rewards: 3.1863716616295927
#
# Episode: 44
# Track generation: 1199..1503 -> 304-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0735 - mean_squared_error: 0.1989
# Ending episode: done False, negative rewards 51
# Total frames in episode: 61
# Replay buffer size: 2866
# Total frame count: 2866
# Epsilon: 0.9460000000000006
# Total reward for episode: 2.0026402640260415
# Running average rewards: 3.160066519460625
#
# Episode: 45
# Track generation: 1228..1539 -> 311-tiles track
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0876 - mean_squared_error: 0.3669
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0813 - mean_squared_error: 0.2077
# Ending episode: done False, negative rewards 51
# Total frames in episode: 105
# Replay buffer size: 2971
# Total frame count: 2971
# Epsilon: 0.9415000000000007
# Total reward for episode: -25.870967741935928
# Running average rewards: 2.5289570789954823
#
# Episode: 46
# Track generation: 1121..1405 -> 284-tiles track
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0544 - mean_squared_error: 0.1785
# Ending episode: done False, negative rewards 51
# Total frames in episode: 60
# Replay buffer size: 3031
# Total frame count: 3031
# Epsilon: 0.9370000000000007
# Total reward for episode: 14.869257950529665
# Running average rewards: 2.791516672006848
#
# Episode: 47
# Track generation: 1027..1289 -> 262-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1112..1401 -> 289-tiles track
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0554 - mean_squared_error: 0.1284
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1296 - mean_squared_error: 0.4018
# Ending episode: done False, negative rewards 51
# Total frames in episode: 74
# Replay buffer size: 3105
# Total frame count: 3105
# Epsilon: 0.9325000000000008
# Total reward for episode: 32.90000000000106
# Running average rewards: 3.4187767413400594
#
# Episode: 48
# Track generation: 1159..1453 -> 294-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0464 - mean_squared_error: 0.1030
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 3161
# Total frame count: 3161
# Epsilon: 0.9280000000000008
# Total reward for episode: -5.335153583618059
# Running average rewards: 3.2401251020552
#
# Episode: 49
# Track generation: 1278..1602 -> 324-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1054 - mean_squared_error: 0.3310
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 3216
# Total frame count: 3216
# Epsilon: 0.9235000000000009
# Total reward for episode: -9.616099071207692
# Running average rewards: 2.9830006185899425
#
# Episode: 50
# Track generation: 1128..1414 -> 286-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0932 - mean_squared_error: 0.2718
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 3272
# Total frame count: 3272
# Epsilon: 0.9190000000000009
# Total reward for episode: -4.856140350877514
# Running average rewards: 2.829291972129796
#
# Episode: 51
# Track generation: 997..1257 -> 260-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0897 - mean_squared_error: 0.2223
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0521 - mean_squared_error: 0.1797
# Ending episode: done False, negative rewards 51
# Total frames in episode: 124
# Replay buffer size: 3396
# Total frame count: 3396
# Epsilon: 0.914500000000001
# Total reward for episode: -7.1289575289582565
# Running average rewards: 2.6377871740319487
#
# Episode: 52
# Track generation: 1094..1371 -> 277-tiles track
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1208 - mean_squared_error: 0.4002
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0736 - mean_squared_error: 0.2782
# Ending episode: done False, negative rewards 51
# Total frames in episode: 60
# Replay buffer size: 3456
# Total frame count: 3456
# Epsilon: 0.910000000000001
# Total reward for episode: 12.231884057970674
# Running average rewards: 2.8188078699553207
#
# Episode: 53
# Track generation: 938..1179 -> 241-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1208..1514 -> 306-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0637 - mean_squared_error: 0.1877
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 3512
# Total frame count: 3512
# Epsilon: 0.9055000000000011
# Total reward for episode: -2.7278688524593235
# Running average rewards: 2.7160916343550494
#
# Episode: 54
# Track generation: 1038..1301 -> 263-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1135 - mean_squared_error: 0.3019
# Ending episode: done False, negative rewards 51
# Total frames in episode: 64
# Replay buffer size: 3576
# Total frame count: 3576
# Epsilon: 0.9010000000000011
# Total reward for episode: 12.567938931297334
# Running average rewards: 2.895216130663091
#
# Episode: 55
# Track generation: 1165..1470 -> 305-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1410 - mean_squared_error: 0.5585
# Ending episode: done False, negative rewards 51
# Total frames in episode: 54
# Replay buffer size: 3630
# Total frame count: 3630
# Epsilon: 0.8965000000000012
# Total reward for episode: -11.731578947368668
# Running average rewards: 2.6340233614125244
#
# Episode: 56
# Track generation: 1179..1478 -> 299-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0871 - mean_squared_error: 0.2488
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 3686
# Total frame count: 3686
# Epsilon: 0.8920000000000012
# Total reward for episode: -5.621476510067435
# Running average rewards: 2.489190030333929
#
# Episode: 57
# Track generation: 1173..1477 -> 304-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0633 - mean_squared_error: 0.1917
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 3742
# Total frame count: 3742
# Epsilon: 0.8875000000000013
# Total reward for episode: -5.898349834983826
# Running average rewards: 2.3445772740353465
#
# Episode: 58
# Track generation: 1075..1348 -> 273-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0510 - mean_squared_error: 0.1208
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2043 - mean_squared_error: 0.7373
# Ending episode: done False, negative rewards 51
# Total frames in episode: 67
# Replay buffer size: 3809
# Total frame count: 3809
# Epsilon: 0.8830000000000013
# Total reward for episode: 17.317647058823326
# Running average rewards: 2.5983581178453123
#
# Episode: 59
# Track generation: 1205..1510 -> 305-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0729 - mean_squared_error: 0.2249
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 3866
# Total frame count: 3866
# Epsilon: 0.8785000000000014
# Total reward for episode: 0.22631578947336806
# Running average rewards: 2.5588240790391135
#
# Episode: 60
# Track generation: 1016..1282 -> 266-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1312 - mean_squared_error: 0.3531
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0444 - mean_squared_error: 0.1164
# Ending episode: done False, negative rewards 51
# Total frames in episode: 87
# Replay buffer size: 3953
# Total frame count: 3953
# Epsilon: 0.8740000000000014
# Total reward for episode: -4.611320754717468
# Running average rewards: 2.4412807211086776
#
# Episode: 61
# Track generation: 1059..1328 -> 269-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1493 - mean_squared_error: 0.4138
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 4009
# Total frame count: 4009
# Epsilon: 0.8695000000000015
# Total reward for episode: -0.011940298507770564
# Running average rewards: 2.4017126401471223
#
# Episode: 62
# Track generation: 1247..1563 -> 316-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1179 - mean_squared_error: 0.3303
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 4064
# Total frame count: 4064
# Epsilon: 0.8650000000000015
# Total reward for episode: -9.301587301587578
# Running average rewards: 2.215945974405302
#
# Episode: 63
# Track generation: 1178..1480 -> 302-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1261..1580 -> 319-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1028 - mean_squared_error: 0.2676
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 4119
# Total frame count: 4119
# Epsilon: 0.8605000000000016
# Total reward for episode: -9.421383647799008
# Running average rewards: 2.034112699058359
#
# Episode: 64
# Track generation: 1072..1348 -> 276-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1344 - mean_squared_error: 0.4349
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 4175
# Total frame count: 4175
# Epsilon: 0.8560000000000016
# Total reward for episode: -4.2181818181821455
# Running average rewards: 1.9379235526392744
#
# Episode: 65
# Track generation: 1352..1694 -> 342-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0572 - mean_squared_error: 0.1631
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 4231
# Total frame count: 4231
# Epsilon: 0.8515000000000017
# Total reward for episode: -7.737243401759802
# Running average rewards: 1.791330113936258
#
# Episode: 66
# Track generation: 1100..1379 -> 279-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1022 - mean_squared_error: 0.2909
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 4288
# Total frame count: 4288
# Epsilon: 0.8470000000000018
# Total reward for episode: -1.2172661870506758
# Running average rewards: 1.7464256915334682
#
# Episode: 67
# Track generation: 1309..1640 -> 331-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0680 - mean_squared_error: 0.2284
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 4344
# Total frame count: 4344
# Epsilon: 0.8425000000000018
# Total reward for episode: -7.248484848485145
# Running average rewards: 1.614147595356724
#
# Episode: 68
# Track generation: 1193..1496 -> 303-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1466 - mean_squared_error: 0.4410
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1262 - mean_squared_error: 0.3880
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 4401
# Total frame count: 4401
# Epsilon: 0.8380000000000019
# Total reward for episode: -2.9324503311261623
# Running average rewards: 1.5482548717845082
#
# Episode: 69
# Track generation: 1164..1459 -> 295-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0809 - mean_squared_error: 0.2067
# Ending episode: done False, negative rewards 51
# Total frames in episode: 61
# Replay buffer size: 4462
# Total frame count: 4462
# Epsilon: 0.8335000000000019
# Total reward for episode: 13.014965986394216
# Running average rewards: 1.7120650305646468
#
# Episode: 70
# Track generation: 1152..1444 -> 292-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1407 - mean_squared_error: 0.4656
# Ending episode: done False, negative rewards 51
# Total frames in episode: 62
# Replay buffer size: 4524
# Total frame count: 4524
# Epsilon: 0.829000000000002
# Total reward for episode: 13.00068728522303
# Running average rewards: 1.8710597102077227
#
# Episode: 71
# Track generation: 1147..1438 -> 291-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0815 - mean_squared_error: 0.1985
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 4579
# Total frame count: 4579
# Epsilon: 0.824500000000002
# Total reward for episode: -8.206896551724448
# Running average rewards: 1.7310880954586645
#
# Episode: 72
# Track generation: 1051..1322 -> 271-tiles track
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1481 - mean_squared_error: 0.4575
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 4636
# Total frame count: 4636
# Epsilon: 0.8200000000000021
# Total reward for episode: -0.5777777777781097
# Running average rewards: 1.699459795825284
#
# Episode: 73
# Track generation: 1145..1435 -> 290-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0600 - mean_squared_error: 0.1361
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 4691
# Total frame count: 4691
# Epsilon: 0.8155000000000021
# Total reward for episode: -8.15916955017332
# Running average rewards: 1.566235074933411
#
# Episode: 74
# Track generation: 1212..1519 -> 307-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0874 - mean_squared_error: 0.3004
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1066 - mean_squared_error: 0.2832
# Ending episode: done False, negative rewards 51
# Total frames in episode: 75
# Replay buffer size: 4766
# Total frame count: 4766
# Epsilon: 0.8110000000000022
# Total reward for episode: -0.5882352941180571
# Running average rewards: 1.537508803346058
#
# Episode: 75
# Track generation: 1100..1380 -> 280-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1025 - mean_squared_error: 0.3186
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 4822
# Total frame count: 4822
# Epsilon: 0.8065000000000022
# Total reward for episode: -4.478853046595301
# Running average rewards: 1.458346147425777
#
# Episode: 76
# Track generation: 1240..1554 -> 314-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1249 - mean_squared_error: 0.3789
# Ending episode: done False, negative rewards 51
# Total frames in episode: 68
# Replay buffer size: 4890
# Total frame count: 4890
# Epsilon: 0.8020000000000023
# Total reward for episode: 30.307987220447743
# Running average rewards: 1.8330168107117764
#
# Episode: 77
# Track generation: 1100..1385 -> 285-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1023 - mean_squared_error: 0.2978
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0954 - mean_squared_error: 0.2602
# Ending episode: done False, negative rewards 51
# Total frames in episode: 72
# Replay buffer size: 4962
# Total frame count: 4962
# Epsilon: 0.7975000000000023
# Total reward for episode: 24.016901408450934
# Running average rewards: 2.1174255876058683
#
# Episode: 78
# Track generation: 1171..1468 -> 297-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0999 - mean_squared_error: 0.2481
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 5018
# Total frame count: 5018
# Epsilon: 0.7930000000000024
# Total reward for episode: -2.129729729730048
# Running average rewards: 2.063664127892755
#
# Episode: 79
# Track generation: 1051..1318 -> 267-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0438 - mean_squared_error: 0.1495
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 5074
# Total frame count: 5074
# Epsilon: 0.7885000000000024
# Total reward for episode: -3.6030075187973196
# Running average rewards: 1.9928307323091297
#
# Episode: 80
# Track generation: 1074..1347 -> 273-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0455 - mean_squared_error: 0.1011
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 5129
# Total frame count: 5129
# Epsilon: 0.7840000000000025
# Total reward for episode: -7.294117647059128
# Running average rewards: 1.8781770486132252
#
# Episode: 81
# Track generation: 1232..1544 -> 312-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0824 - mean_squared_error: 0.1975
# Ending episode: done False, negative rewards 51
# Total frames in episode: 58
# Replay buffer size: 5187
# Total frame count: 5187
# Epsilon: 0.7795000000000025
# Total reward for episode: 2.5234726688099727
# Running average rewards: 1.8860465073961123
#
# Episode: 82
# Track generation: 1210..1517 -> 307-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0432 - mean_squared_error: 0.0915
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0366 - mean_squared_error: 0.0848
# Ending episode: done False, negative rewards 51
# Total frames in episode: 69
# Replay buffer size: 5256
# Total frame count: 5256
# Epsilon: 0.7750000000000026
# Total reward for episode: 5.07973856209113
# Running average rewards: 1.9245247249225585
#
# Episode: 83
# Track generation: 1096..1374 -> 278-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0369 - mean_squared_error: 0.0826
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 5311
# Total frame count: 5311
# Epsilon: 0.7705000000000026
# Total reward for episode: -7.5595667870039165
# Running average rewards: 1.8116188735901004
#
# Episode: 84
# Track generation: 1272..1594 -> 322-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0586 - mean_squared_error: 0.1343
# Ending episode: done False, negative rewards 51
# Total frames in episode: 65
# Replay buffer size: 5376
# Total frame count: 5376
# Epsilon: 0.7660000000000027
# Total reward for episode: 26.9595015576326
# Running average rewards: 2.107476316931777
#
# Episode: 85
# Track generation: 1323..1657 -> 334-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0391 - mean_squared_error: 0.0822
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 5433
# Total frame count: 5433
# Epsilon: 0.7615000000000027
# Total reward for episode: -4.781981981982312
# Running average rewards: 2.0273663367118457
#
# Episode: 86
# Track generation: 1077..1350 -> 273-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0403 - mean_squared_error: 0.0972
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1020 - mean_squared_error: 0.2829
# Ending episode: done False, negative rewards 51
# Total frames in episode: 109
# Replay buffer size: 5542
# Total frame count: 5542
# Epsilon: 0.7570000000000028
# Total reward for episode: 11.547058823528822
# Running average rewards: 2.13678808943388
#
# Episode: 87
# Track generation: 1236..1549 -> 313-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0719 - mean_squared_error: 0.1815
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0455 - mean_squared_error: 0.0982
# Ending episode: done False, negative rewards 51
# Total frames in episode: 61
# Replay buffer size: 5603
# Total frame count: 5603
# Epsilon: 0.7525000000000028
# Total reward for episode: 7.651282051281697
# Running average rewards: 2.1994527935457864
#
# Episode: 88
# Track generation: 1060..1329 -> 269-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0943 - mean_squared_error: 0.2775
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 5659
# Total frame count: 5659
# Epsilon: 0.7480000000000029
# Total reward for episode: -3.7432835820898624
# Running average rewards: 2.1326804747184194
#
# Episode: 89
# Track generation: 1206..1512 -> 306-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0500 - mean_squared_error: 0.1292
# Ending episode: done False, negative rewards 51
# Total frames in episode: 60
# Replay buffer size: 5719
# Total frame count: 5719
# Epsilon: 0.7435000000000029
# Total reward for episode: 8.786885245901317
# Running average rewards: 2.206616083287118
#
# Episode: 90
# Track generation: 1103..1402 -> 299-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1080..1358 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1220..1529 -> 309-tiles track
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0539 - mean_squared_error: 0.1458
# Ending episode: done False, negative rewards 51
# Total frames in episode: 66
# Replay buffer size: 5785
# Total frame count: 5785
# Epsilon: 0.739000000000003
# Total reward for episode: 19.054545454545043
# Running average rewards: 2.3917581642899526
#
# Episode: 91
# Track generation: 1256..1574 -> 318-tiles track
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0577 - mean_squared_error: 0.1558
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 5841
# Total frame count: 5841
# Epsilon: 0.734500000000003
# Total reward for episode: -6.627129337539742
# Running average rewards: 2.293726778400499
#
# Episode: 92
# Track generation: 1324..1659 -> 335-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0941 - mean_squared_error: 0.2279
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0435 - mean_squared_error: 0.0978
# Ending episode: done False, negative rewards 51
# Total frames in episode: 64
# Replay buffer size: 5905
# Total frame count: 5905
# Epsilon: 0.7300000000000031
# Total reward for episode: 1.3461077844307674
# Running average rewards: 2.2835373268524375
#
# Episode: 93
# Track generation: 1088..1364 -> 276-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0468 - mean_squared_error: 0.1038
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 5962
# Total frame count: 5962
# Epsilon: 0.7255000000000031
# Total reward for episode: 2.654545454545115
# Running average rewards: 2.2874842218278912
#
# Episode: 94
# Track generation: 1084..1359 -> 275-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0118 - mean_squared_error: 0.0237
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 6017
# Total frame count: 6017
# Epsilon: 0.7210000000000032
# Total reward for episode: -7.401459854014917
# Running average rewards: 2.1854953368190198
#
# Episode: 95
# Track generation: 1069..1341 -> 272-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0757 - mean_squared_error: 0.2270
# Ending episode: done False, negative rewards 51
# Total frames in episode: 61
# Replay buffer size: 6078
# Total frame count: 6078
# Epsilon: 0.7165000000000032
# Total reward for episode: 12.500369003689677
# Running average rewards: 2.29294193751559
#
# Episode: 96
# Track generation: 1196..1499 -> 303-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0841 - mean_squared_error: 0.4286
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 6135
# Total frame count: 6135
# Epsilon: 0.7120000000000033
# Total reward for episode: -2.9324503311261623
# Running average rewards: 2.2390719141275306
#
# Episode: 97
# Track generation: 1278..1601 -> 323-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0673 - mean_squared_error: 0.1971
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 6191
# Total frame count: 6191
# Epsilon: 0.7075000000000033
# Total reward for episode: -6.872049689441312
# Running average rewards: 2.146101285519685
#
# Episode: 98
# Track generation: 1060..1329 -> 269-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0653 - mean_squared_error: 0.1653
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 6248
# Total frame count: 6248
# Epsilon: 0.7030000000000034
# Total reward for episode: -0.41194029850777625
# Running average rewards: 2.12026248164062
#
# Episode: 99
# Track generation: 1113..1395 -> 282-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0451 - mean_squared_error: 0.1258
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0699 - mean_squared_error: 0.2024
# Ending episode: done False, negative rewards 51
# Total frames in episode: 60
# Replay buffer size: 6308
# Total frame count: 6308
# Epsilon: 0.6985000000000035
# Total reward for episode: 15.145907473309258
# Running average rewards: 2.2505189315573064
#
# Episode: 100
# Track generation: 971..1225 -> 254-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1200 - mean_squared_error: 0.4347
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 6363
# Total frame count: 6363
# Epsilon: 0.6940000000000035
# Total reward for episode: -6.189723320158411
# Running average rewards: 2.166952176589824
#
# Episode: 101
# Track generation: 1153..1445 -> 292-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0563 - mean_squared_error: 0.1709
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1305 - mean_squared_error: 0.3808
# Ending episode: done False, negative rewards 51
# Total frames in episode: 89
# Replay buffer size: 6452
# Total frame count: 6452
# Epsilon: 0.6895000000000036
# Total reward for episode: 2.2006872852228803
# Running average rewards: 2.1672829129489712
#
# Episode: 102
# Track generation: 1073..1351 -> 278-tiles track
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0958 - mean_squared_error: 0.2955
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0685 - mean_squared_error: 0.2208
# Ending episode: done False, negative rewards 51
# Total frames in episode: 114
# Replay buffer size: 6566
# Total frame count: 6566
# Epsilon: 0.6850000000000036
# Total reward for episode: 8.551624548735838
# Running average rewards: 2.2292668123255432
#
# Episode: 103
# Track generation: 1113..1402 -> 289-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0374 - mean_squared_error: 0.0929
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 6622
# Total frame count: 6622
# Epsilon: 0.6805000000000037
# Total reward for episode: -5.038888888889208
# Running average rewards: 2.1593806998138625
#
# Episode: 104
# Track generation: 1071..1343 -> 272-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0556 - mean_squared_error: 0.2022
# Ending episode: done False, negative rewards 51
# Total frames in episode: 58
# Replay buffer size: 6680
# Total frame count: 6680
# Epsilon: 0.6760000000000037
# Total reward for episode: 2.630258302582689
# Running average rewards: 2.163865248411661
#
# Episode: 105
# Track generation: 1216..1524 -> 308-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1171 - mean_squared_error: 0.4302
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 6736
# Total frame count: 6736
# Epsilon: 0.6715000000000038
# Total reward for episode: -6.113355048860257
# Running average rewards: 2.0857782644751333
#
# Episode: 106
# Track generation: 1194..1497 -> 303-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0529 - mean_squared_error: 0.1399
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0577 - mean_squared_error: 0.1326
# Ending episode: done False, negative rewards 51
# Total frames in episode: 78
# Replay buffer size: 6814
# Total frame count: 6814
# Epsilon: 0.6670000000000038
# Total reward for episode: 64.82649006622671
# Running average rewards: 2.6721400570148672
#
# Episode: 107
# Track generation: 1084..1367 -> 283-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0573 - mean_squared_error: 0.1777
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1000 - mean_squared_error: 0.3244
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0555 - mean_squared_error: 0.2460
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1083 - mean_squared_error: 0.2991
# Ending episode: done False, negative rewards 51
# Total frames in episode: 219
# Replay buffer size: 7033
# Total frame count: 7033
# Epsilon: 0.6625000000000039
# Total reward for episode: 15.236879432622878
# Running average rewards: 2.788480236418645
#
# Episode: 108
# Track generation: 1232..1544 -> 312-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0377 - mean_squared_error: 0.0906
# Ending episode: done False, negative rewards 51
# Total frames in episode: 55
# Replay buffer size: 7088
# Total frame count: 7088
# Epsilon: 0.6580000000000039
# Total reward for episode: -9.13826366559514
# Running average rewards: 2.6790605675928303
#
# Episode: 109
# Track generation: 1288..1616 -> 328-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1300..1628 -> 328-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1077 - mean_squared_error: 0.4842
# Ending episode: done False, negative rewards 51
# Total frames in episode: 56
# Replay buffer size: 7144
# Total frame count: 7144
# Epsilon: 0.653500000000004
# Total reward for episode: -7.109480122324467
# Running average rewards: 2.5900738340481277
#
# Episode: 110
# Track generation: 1048..1314 -> 266-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0894 - mean_squared_error: 0.3625
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0676 - mean_squared_error: 0.1755
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0280 - mean_squared_error: 0.0636
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0485 - mean_squared_error: 0.1472
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0345 - mean_squared_error: 0.0771
# Ending episode: done False, negative rewards 51
# Total frames in episode: 216
# Replay buffer size: 7360
# Total frame count: 7360
# Epsilon: 0.649000000000004
# Total reward for episode: -14.701886792454008
# Running average rewards: 2.4342904049805414
#
# Episode: 111
# Track generation: 1051..1318 -> 267-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0446 - mean_squared_error: 0.1093
# Ending episode: done False, negative rewards 51
# Total frames in episode: 64
# Replay buffer size: 7424
# Total frame count: 7424
# Epsilon: 0.6445000000000041
# Total reward for episode: 19.51278195488723
# Running average rewards: 2.586776936676137
#
# Episode: 112
# Track generation: 1220..1529 -> 309-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - mean_squared_error: 0.0761
# Ending episode: done False, negative rewards 51
# Total frames in episode: 61
# Replay buffer size: 7485
# Total frame count: 7485
# Epsilon: 0.6400000000000041
# Total reward for episode: 4.820779220778853
# Running average rewards: 2.6065468683938597
#
# Episode: 113
# Track generation: 1273..1595 -> 322-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1015 - mean_squared_error: 0.2797
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0821 - mean_squared_error: 0.2151
# Ending episode: done False, negative rewards 51
# Total frames in episode: 65
# Replay buffer size: 7550
# Total frame count: 7550
# Epsilon: 0.6355000000000042
# Total reward for episode: 2.037383177569737
# Running average rewards: 2.601554204439262
#
# Episode: 114
# Track generation: 979..1228 -> 249-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0192 - mean_squared_error: 0.0398
# Ending episode: done False, negative rewards 51
# ...
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0773 - mean_squared_error: 0.6504
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0815 - mean_squared_error: 0.3460
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2588 - mean_squared_error: 2.3805
# Ending episode: done False, negative rewards 51
# Total frames in episode: 114
# Replay buffer size: 29303
# Total frame count: 29303
# Epsilon: 0.1
# Total reward for episode: 131.27074829932184
# Running average rewards: 41.03245162828858
#
# Episode: 368
# Track generation: 1408..1764 -> 356-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0593 - mean_squared_error: 0.1951
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 29360
# Total frame count: 29360
# Epsilon: 0.1
# Total reward for episode: -3.081690140845396
# Running average rewards: 40.912901108589026
#
# Episode: 369
# Track generation: 1186..1487 -> 301-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0981 - mean_squared_error: 0.4979
# Ending episode: done False, negative rewards 51
# Total frames in episode: 62
# Replay buffer size: 29422
# Total frame count: 29422
# Epsilon: 0.1
# Total reward for episode: 18.53333333333301
# Running average rewards: 40.852415790277526
#
# Episode: 370
# Track generation: 1305..1635 -> 330-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1766 - mean_squared_error: 0.7970
# Ending episode: done False, negative rewards 51
# Total frames in episode: 58
# Replay buffer size: 29480
# Total frame count: 29480
# Epsilon: 0.1
# Total reward for episode: 4.1556231003036075
# Running average rewards: 40.753502602433926
#
# Episode: 371
# Track generation: 1284..1609 -> 325-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1164 - mean_squared_error: 0.6259
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2002 - mean_squared_error: 1.5441
# Ending episode: done False, negative rewards 51
# Total frames in episode: 98
# Replay buffer size: 29578
# Total frame count: 29578
# Epsilon: 0.1
# Total reward for episode: 161.41728395061944
# Running average rewards: 41.07786760605808
#
# Episode: 372
# Track generation: 1111..1393 -> 282-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1973 - mean_squared_error: 1.2188
# Ending episode: done False, negative rewards 51
# Total frames in episode: 69
# Replay buffer size: 29647
# Total frame count: 29647
# Epsilon: 0.1
# Total reward for episode: 47.13309608541056
# Running average rewards: 41.09410146257109
#
# Episode: 373
# Track generation: 1160..1453 -> 293-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2346 - mean_squared_error: 2.0539
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1216 - mean_squared_error: 0.4499
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 29704
# Total frame count: 29704
# Epsilon: 0.1
# Total reward for episode: 1.1726027397257148
# Running average rewards: 40.98735948737632
#
# Episode: 374
# Track generation: 1205..1510 -> 305-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1815 - mean_squared_error: 1.1761
# Ending episode: done False, negative rewards 51
# Total frames in episode: 62
# Replay buffer size: 29766
# Total frame count: 29766
# Epsilon: 0.1
# Total reward for episode: 21.252631578947195
# Running average rewards: 40.93473354628717
#
# Episode: 375
# Track generation: 967..1221 -> 254-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1545 - mean_squared_error: 0.9984
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 29823
# Total frame count: 29823
# Epsilon: 0.1
# Total reward for episode: 0.9154150197625306
# Running average rewards: 40.82829918850386
#
# Episode: 376
# Track generation: 1099..1379 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1124..1409 -> 285-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2380 - mean_squared_error: 1.5401
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0514 - mean_squared_error: 0.2389
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0919 - mean_squared_error: 0.4770
# Ending episode: done False, negative rewards 51
# Total frames in episode: 147
# Replay buffer size: 29970
# Total frame count: 29970
# Epsilon: 0.1
# Total reward for episode: 71.48169014084728
# Running average rewards: 40.90960791782042
#
# Episode: 377
# Track generation: 1208..1521 -> 313-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1278 - mean_squared_error: 0.5870
# Ending episode: done True, negative rewards 16
# Total frames in episode: 37
# Replay buffer size: 30007
# Total frame count: 30007
# Epsilon: 0.1
# Total reward for episode: -11.835897435896896
# Running average rewards: 40.770069543868786
#
# Episode: 378
# Track generation: 1199..1503 -> 304-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1872 - mean_squared_error: 0.8244
# Ending episode: done False, negative rewards 51
# Total frames in episode: 57
# Replay buffer size: 30064
# Total frame count: 30064
# Epsilon: 0.1
# Total reward for episode: 0.30231023102276566
# Running average rewards: 40.66329445333358
#
# Episode: 379
# Track generation: 1161..1462 -> 301-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1066 - mean_squared_error: 0.3766
# Ending episode: done False, negative rewards 51
# Total frames in episode: 62
# Replay buffer size: 30126
# Total frame count: 30126
# Epsilon: 0.1
# Total reward for episode: 11.866666666666326
# Running average rewards: 40.58751385389498
#
# Episode: 380
# Track generation: 1092..1369 -> 277-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1663 - mean_squared_error: 1.8767
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1261 - mean_squared_error: 0.6737
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1173 - mean_squared_error: 0.3997
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1708 - mean_squared_error: 1.0478
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1114 - mean_squared_error: 0.8008
# Ending episode: done True, negative rewards 39
# Total frames in episode: 238
# Replay buffer size: 30364
# Total frame count: 30364
# Epsilon: 0.1
# Total reward for episode: 107.8985507246415
# Running average rewards: 40.76418324200718
#
# Episode: 381
# Track generation: 1341..1680 -> 339-tiles track
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1356 - mean_squared_error: 0.8452
# Ending episode: done False, negative rewards 51
# Total frames in episode: 65
# Replay buffer size: 30429
# Total frame count: 30429
# Epsilon: 0.1
# Total reward for episode: 33.17159763313658
# Running average rewards: 40.74430736344992
#
# Episode: 382
# Track generation: 1233..1546 -> 313-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1691 - mean_squared_error: 0.9898
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1516 - mean_squared_error: 1.2400
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0785 - mean_squared_error: 0.3493
# Ending episode: done False, negative rewards 51
# Total frames in episode: 146
# Replay buffer size: 30575
# Total frame count: 30575
# Epsilon: 0.1
# Total reward for episode: 92.2410256410287
# Running average rewards: 40.878763546942295
#
# Episode: 383
# Track generation: 1161..1455 -> 294-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1220 - mean_squared_error: 0.4847
# Ending episode: done False, negative rewards 51
# Total frames in episode: 68
# Replay buffer size: 30643
# Total frame count: 30643
# Epsilon: 0.1
# Total reward for episode: 58.12423208191262
# Running average rewards: 40.923673621252114
#
# Episode: 384
# Track generation: 1081..1355 -> 274-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1552 - mean_squared_error: 1.0998
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1467 - mean_squared_error: 1.1494
# Ending episode: done False, negative rewards 51
# Total frames in episode: 80
# Replay buffer size: 30723
# Total frame count: 30723
# Epsilon: 0.1
# Total reward for episode: 103.53113553113701
# Running average rewards: 41.08629040543364
#
# Episode: 385
# Track generation: 1138..1427 -> 289-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1975 - mean_squared_error: 1.7815
# Ending episode: done False, negative rewards 51
# Total frames in episode: 61
# Replay buffer size: 30784
# Total frame count: 30784
# Epsilon: 0.1
# Total reward for episode: 13.794444444444096
# Running average rewards: 41.01558614128599
#
# Episode: 386
# Track generation: 1119..1403 -> 284-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1931 - mean_squared_error: 2.5116
# Ending episode: done False, negative rewards 51
# Total frames in episode: 58
# Replay buffer size: 30842
# Total frame count: 30842
# Epsilon: 0.1
# Total reward for episode: 5.0685512367487675
# Running average rewards: 40.92269974618383
#
# Episode: 387
# Track generation: 1165..1464 -> 299-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1254..1571 -> 317-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2327 - mean_squared_error: 2.7470
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1530 - mean_squared_error: 1.2469
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1803 - mean_squared_error: 1.6603
# Ending episode: done False, negative rewards 51
# Total frames in episode: 126
# Replay buffer size: 30968
# Total frame count: 30968
# Epsilon: 0.1
# Total reward for episode: 209.093670886079
# Running average rewards: 41.35613008417325
#
# Episode: 388
# Track generation: 1093..1370 -> 277-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1672 - mean_squared_error: 0.9084
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0984 - mean_squared_error: 0.3652
# Ending episode: done False, negative rewards 51
# Total frames in episode: 110
# Replay buffer size: 31078
# Total frame count: 31078
# Epsilon: 0.1
# Total reward for episode: 267.5942028985455
# Running average rewards: 41.93771896030274
#
# Episode: 389
# Track generation: 1031..1299 -> 268-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0747 - mean_squared_error: 0.5156
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1192 - mean_squared_error: 1.1036
# Ending episode: done False, negative rewards 51
# Total frames in episode: 100
# Replay buffer size: 31178
# Total frame count: 31178
# Epsilon: 0.1
# Total reward for episode: 68.6142322097396
# Running average rewards: 42.00612027632694
#
# Episode: 390
# Track generation: 1075..1348 -> 273-tiles track
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2212 - mean_squared_error: 1.3731
# Ending episode: done False, negative rewards 51
# Total frames in episode: 60
# Replay buffer size: 31238
# Total frame count: 31238
# Epsilon: 0.1
# Total reward for episode: 16.441176470588005
# Running average rewards: 41.940736788332714
#
# Episode: 391
# Track generation: 1058..1327 -> 269-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1366 - mean_squared_error: 0.7028
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1988 - mean_squared_error: 1.2445
# Ending episode: done False, negative rewards 51
# Total frames in episode: 86
# Replay buffer size: 31324
# Total frame count: 31324
# Epsilon: 0.1
# Total reward for episode: 70.0776119403002
# Running average rewards: 42.012514531067325
#
# Episode: 392
# Track generation: 1192..1494 -> 302-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2364 - mean_squared_error: 1.5859
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1271 - mean_squared_error: 0.5444
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0561 - mean_squared_error: 0.2418
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1457 - mean_squared_error: 0.9124
# Ending episode: done False, negative rewards 51
# Total frames in episode: 197
# Replay buffer size: 31521
# Total frame count: 31521
# Epsilon: 0.1
# Total reward for episode: 216.88106312292484
# Running average rewards: 42.457472669977896
#
# Episode: 393
# Track generation: 1278..1609 -> 331-tiles track
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1307 - mean_squared_error: 0.6782
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1348 - mean_squared_error: 0.6295
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1231 - mean_squared_error: 0.8377
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0992 - mean_squared_error: 0.4204
# Ending episode: done False, negative rewards 51
# Total frames in episode: 219
# Replay buffer size: 31740
# Total frame count: 31740
# Epsilon: 0.1
# Total reward for episode: 279.0666666666617
# Running average rewards: 43.05800361920806
#
# Episode: 394
# Track generation: 1146..1446 -> 300-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1463 - mean_squared_error: 0.6356
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0582 - mean_squared_error: 0.2898
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1564 - mean_squared_error: 1.0266
# Ending episode: done False, negative rewards 51
# Total frames in episode: 146
# Replay buffer size: 31886
# Total frame count: 31886
# Epsilon: 0.1
# Total reward for episode: 142.2688963210734
# Running average rewards: 43.30917043617481
#
# Episode: 395
# Track generation: 997..1259 -> 262-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3225 - mean_squared_error: 5.0207
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1269 - mean_squared_error: 0.8745
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0871 - mean_squared_error: 0.3142
# Ending episode: done False, negative rewards 51
# Total frames in episode: 115
# Replay buffer size: 32001
# Total frame count: 32001
# Epsilon: 0.1
# Total reward for episode: 164.72796934866105
# Running average rewards: 43.6157835647417
#
# Episode: 396
# Track generation: 1180..1479 -> 299-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1498 - mean_squared_error: 1.0288
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1293 - mean_squared_error: 1.1174
# Ending episode: done False, negative rewards 51
# Total frames in episode: 138
# Replay buffer size: 32139
# Total frame count: 32139
# Epsilon: 0.1
# Total reward for episode: 122.65234899329141
# Running average rewards: 43.81486811242066
#
# Episode: 397
# Track generation: 1060..1329 -> 269-tiles track
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2367 - mean_squared_error: 1.8011
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1423 - mean_squared_error: 0.8297
# Ending episode: done False, negative rewards 51
# Total frames in episode: 75
# Replay buffer size: 32214
# Total frame count: 32214
# Epsilon: 0.1
# Total reward for episode: 78.20895522388209
# Running average rewards: 43.90128541672082
#
# Episode: 398
# Track generation: 1143..1433 -> 290-tiles track
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1981 - mean_squared_error: 1.2456
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1594 - mean_squared_error: 0.7256
# Ending episode: done False, negative rewards 51
# Total frames in episode: 130
# Replay buffer size: 32344
# Total frame count: 32344
# Epsilon: 0.1
# Total reward for episode: 231.73702422144947
# Running average rewards: 44.37205167938931
#
# Episode: 399
# Track generation: 1341..1681 -> 340-tiles track
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0988 - mean_squared_error: 0.4871
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2297 - mean_squared_error: 1.8934
# Ending episode: done False, negative rewards 51
# Total frames in episode: 67
# Replay buffer size: 32411
# Total frame count: 32411
# Epsilon: 0.1
# Total reward for episode: 38.09675516224277
# Running average rewards: 44.35636343809645

# %%
env.close()

# %% [markdown]
# ## Analysis

# %%
# Plot the rewards
plt.figure(figsize=(8, 6))
plt.title('DQN Agent')
plt.plot(episode_rewards, label='Episode reward')
plt.plot([np.mean(episode_rewards[::-1][i:i+100]) for i in range(len(episode_rewards))][::-1], label='Average reward (last 100 episodes)')
plt.ylim((-50, 200))
plt.xlabel('episode')
plt.ylabel('reward')
plt.legend()
plt.show()

# %%
idx = 1015

s_0_img = d[idx][0].reshape(56, 56, 3)
s_1_img = d[idx][3].reshape(56, 56, 3)
action = actions[d[idx][1]]

print(f'Action: {action}, reward: {d[idx][2]}')
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))
ax[0, 0].imshow(np.round(s_0_img[:, :, 0]), cmap='gray')
ax[0, 1].imshow(np.round(s_0_img[:, :, 1]), cmap='gray')
ax[0, 2].imshow(np.round(s_0_img[:, :, 2]), cmap='gray')

ax[1, 0].imshow(np.round(s_1_img[:, :, 0]), cmap='gray')
ax[1, 1].imshow(np.round(s_1_img[:, :, 1]), cmap='gray')
ax[1, 2].imshow(np.round(s_1_img[:, :, 2]), cmap='gray')

ax[0, 0].axis('off')
ax[0, 1].axis('off')
ax[0, 2].axis('off')
ax[1, 0].axis('off')
ax[1, 1].axis('off')
ax[1, 2].axis('off')
plt.show()
# Out:
# Action: [0. 1. 0.], reward: -0.4000000000000057

# %%
# Run an episode with the DQN agent
env = gym.make("CarRacing-v0")
s = env.reset()
episode_rewards = 0

for _ in range(100):
    action = dqn_agent(s, actions, model)
    print(action)
    s, reward, done, info = env.step(action) 

    episode_rewards += reward
    if done: 
      break;
            
env.close()

print(f'Total episode rewards: {episode_rewards}')
# Out:
# Track generation: 1008..1267 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1203..1508 -> 305-tiles track
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 6>()
#       4 episode_rewards = 0
#       6 for _ in range(100):
# ----> 7     action = dqn_agent(s, actions, model)
#       8     print(action)
#       9     s, reward, done, info = env.step(action)
#
# Input In [13], in dqn_agent(s, actions, model)
#     155 """Returns the best action as learnt by the DQN agent."""
#     156 s = np.reshape(s, (1, 96, 96, 3))
# --> 157 action_index = np.argmax(model.predict(s))
#     158 return actions[action_index]
#
# File /anaconda/envs/gymenv/lib/python3.10/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File /anaconda/envs/gymenv/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
# -> 1147     raise e.ag_error_metadata.to_exception(e)
#    1148   else:
#    1149     raise
#
# ValueError: in user code:
#
#     File "/anaconda/envs/gymenv/lib/python3.10/site-packages/keras/engine/training.py", line 1801, in predict_function  *
#         return step_function(self, iterator)
#     File "/anaconda/envs/gymenv/lib/python3.10/site-packages/keras/engine/training.py", line 1790, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/anaconda/envs/gymenv/lib/python3.10/site-packages/keras/engine/training.py", line 1783, in run_step  **
#         outputs = model.predict_step(data)
#     File "/anaconda/envs/gymenv/lib/python3.10/site-packages/keras/engine/training.py", line 1751, in predict_step
#         return self(x, training=False)
#     File "/anaconda/envs/gymenv/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/anaconda/envs/gymenv/lib/python3.10/site-packages/keras/engine/input_spec.py", line 264, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_1" is incompatible with the layer: expected shape=(None, 56, 56, 3), found shape=(None, 96, 96, 3)

# %% [markdown]
# ### Render the DQN agent

# %%
"""
Utility functions to enable video recording of gym environment 
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
# Run the agent and render epsiode as video
env = wrap_env(gym.make("CarRacing-v0"))
s = env.reset()

while True:
    env.render()
    
    action = dqn_agent(s, actions, model)
    s, reward, done, info = env.step(action) 
   
    if done: 
      break;
            
env.close()
show_video()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Track generation: 1223..1533 -> 310-tiles track
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
def create_q_model():
    """Returns a CNN model."""

    model = Sequential()
    model.add(Conv2D(32, 8, activation='relu', strides=4,
            input_shape=(56, 56, 3,)))
    model.add(Conv2D(64, 4, activation='relu', strides=2))
    model.add(Conv2D(64, 3, activation='relu', strides=1))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dense(num_actions, activation="linear"))

    return model

def create_q_model_2():
    """Returns a CNN model."""

    model = Sequential()
    model.add(Conv2D(16, 12, activation='relu', strides=4,
            input_shape=(96, 96, 3,)))
    model.add(Conv2D(32, 8, activation='relu', strides=2))
    model.add(Conv2D(64, 4, activation='relu', strides=2))
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(num_actions, activation="linear"))

    return model

def cnn_model():
    """Returns a CNN model."""

    model = Sequential()
    model.add(Conv2D(32, (4, 4), activation='relu', strides=1,
            input_shape=(96, 96, 3,)))
    model.add(Conv2D(64, (4, 4), activation='relu', strides=2))
    model.add(Conv2D(128, (4, 4), activation='relu', strides=2))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dense(num_actions, activation="linear"))

    return model

def build_model():
    """ Neural Net for Deep-Q learning Model"""

    model = Sequential()
    model.add(Conv2D(filters=6, kernel_size=(7, 7), strides=3, activation='relu', input_shape=(56, 56, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(filters=12, kernel_size=(4, 4), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(216, activation='relu'))
    model.add(Dense(num_actions, activation=None))

    return model

# %%
def rgb2gray(rgb):
    """Converts RGB image to grayscale.
        https://stackoverflow.com/questions/63900600/turn-a-image-to-grayscale-in-python
    """

    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140]).astype(np.int16)

# %%
action = [0.0, 1.0, 0.0]
gs_buffer = deque()

frame_count = 0

env = gym.make("CarRacing-v0")
s_prev = env.reset()
for i in range(50):

    action_reward = 0

    for _ in range(2):
        s_1, reward, done, info = env.step(action)
        s_1 = s_1[20:76, 20:76, :]
        s_1_gs = rgb2gray(s_1)
        frame_count+=1
        action_reward += reward

    gs_buffer.append((s_1_gs, frame_count, round(action_reward, 2)))

    if i%3==0 and i>0:
        img = np.zeros((56, 56, 3))
        img[:, :, 0] = gs_buffer[0][0]
        img[:, :, 1] = gs_buffer[1][0]
        img[:, :, 2] = gs_buffer[2][0]

        fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(8, 8))
        ax[0].imshow(img[:, :, 0], cmap='gray')
        ax[1].imshow(img[:, :, 1], cmap='gray')
        ax[2].imshow(img[:, :, 2], cmap='gray')

        ax[0].set_title(f'frame: {gs_buffer[0][1]}, reward: {gs_buffer[0][2]}')
        ax[1].set_title(f'frame: {gs_buffer[1][1]}, reward: {gs_buffer[1][2]}')
        ax[2].set_title(f'frame: {gs_buffer[2][1]}, reward: {gs_buffer[1][2]}')

        ax[0].axis('off')
        ax[1].axis('off')
        ax[2].axis('off')
        plt.show()

        # Remove first image from buffer
        gs_buffer.popleft()

    s_prev = s_1.copy()

env.close()
